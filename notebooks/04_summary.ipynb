# %% [markdown]
# # **Project Summary**

# %% [markdown]
# ## **Key findings**

# %% [markdown]
# - Học sinh nam ở độ tuổi 21–22 có điểm G3 giảm mạnh, trong khi nữ giới duy trì xu hướng ổn định hơn
# - Sau 18 tuổi, mối quan hệ studytime → điểm số gần như biến mất
# - Nam và Nữ không học hiệu quả theo cùng một cách: điểm số của Nam giới vượt trội Nữ giới ở mức học thấp (<5h), ở mức học cao (>10h) thì ngược lại
# - Việc có hay không được gia đình hỗ trợ học tập (famsup) không làm thay đổi đáng kể điểm số
# - Internet không có tác động đồng nhất – hiệu quả phụ thuộc vào goout và freetime

# %% [markdown]
# ## **Limitations**
#
# **Dataset Limitations:**
# - Kích thước mẫu không đồng đều giữa các nhóm (ví dụ: rất ít học sinh 21-22 tuổi, Medu/Fedu=0), ảnh hưởng độ tin cậy thống kê ở một số phân tích.
# - Dữ liệu cross-sectional (cắt ngang) nên chỉ thấy tương quan (correlation) chứ chưa khẳng định nhân quả (causation).
# - Thiếu thông tin chi tiết về cách sử dụng Internet (học tập vs giải trí), chất lượng hỗ trợ gia đình (famsup), và nguyên nhân nghỉ học (absences).
#
# **Analysis Limitations:**
# - Chưa sử dụng phương pháp nâng cao như XGBoost, Neural Networks, hoặc stacking ensemble cho bài toán dự đoán rượu bia.
# - Chưa thực hiện feature selection chi tiết (RFE, LASSO) hay hyperparameter tuning tối ưu (Grid Search, Bayesian Optimization) cho các mô hình machine learning.
# - Một số kiểm định thống kê (như ANOVA cho Age Groups) không có ý nghĩa thống kê dù biểu đồ cho thấy xu hướng, có thể do sample size nhỏ.
# - Dù đã phân tích tương tác 2 chiều, nhưng chưa xây dựng mô hình hồi quy đa biến đầy đủ (multiple regression) với các interaction terms để kiểm soát đồng thời nhiều yếu tố.
#
# **Scope Limitations:**
# - Chỉ phân tích 2 môn học (Toán và tiếng Bồ Đào Nha) của học sinh Bồ Đào Nha, chưa thể khẳng định kết quả áp dụng rộng rãi cho các môn khác hay quốc gia khác.
# - Không xem xét tác động của giáo viên, chất lượng trường học, hoặc các yếu tố môi trường xã hội rộng hơn.
# - Chưa phân tích tác động dài hạn của các yếu tố lên sự nghiệp học tập sau này.
# - Chưa xem xét các yếu tố tâm lý, sức khỏe tinh thần có thể ảnh hưởng đến học tập và thói quen sinh hoạt do thiếu các feature tương ứng trong dữ liệu.

# %% [markdown]
# ## **Future Direction**

# %% [markdown]
# **Cải thiện dữ liệu**
# - Mở rộng phạm vi nghiên cứu: hiện tại bộ dữ liệu chỉ được khảo sát trên 2 môn Toán và Bồ Đào Nha của 2 trường trung học $\rightarrow$ Cần mở rộng thu nhập dữ liệu từ nhiều quốc gia để kiểm chứng xem liệu các yếu tố có tác động giống nhau hay không.
# - Nghiên cứu theo chiều dọc: thay vì chỉ phân tích dữ liệu tại một thời điểm, theo dõi và phân tích hồ sơ học sinh xuyên suốt các năm của học sinh trung học để xem rõ mối quan hệ nhân quả.
#
# **Advanced Modeling**
# - Áp dụng mô hình học máy nâng cao: thử các thuật toán Ensemble như XGBoost, CatBoost. Các thuật toán này có khả năng xử lý mất cân bằng dữ liệu và nắm được các mối quan hệ phi tuyến phức tạp tốt hơn Decision Tree hay Logistic Regression.
#
# **Practical Deployment**
# - Hệ thống Cảnh báo sớm: Phát triển Dashboard thời gian thực dành cho nhà trường. Hệ thống sẽ dùng điểm số `G1` và các feature trên để tự động nhận diện và gắn cờ những học sinh có nguy cơ trượt môn cao $\rightarrow$ Giúp giáo viên can thiệp kịp thời.
# - Cá nhân hoá lộ trình hỗ trợ: Sử dụng Clustering để nhóm các học sinh có cùng đặc điểm rủi ro và thiết kế các chương trình tư vấn tâm ly hoặc phụ đạo được cá nhân hoá riêng cho từng nhóm để có thể ủng hộ về mặt tinh thần cho học sinh.

# %% [markdown]
# # **Individual Reflections**

# %% [markdown]
# ## **Trần Mạnh Hùng - 22120177**
#
# ### **Challenges & Difficulties**
# -**Specific Obstacle**: Khó khăn lớn mà em gặp phải là trong giai đoạn đặt câu hỏi nghiên cứu. Em chưa biết cách xây dựng một câu hỏi đủ rõ ràng, có định hướng và thực sự có khả năng khai thác được insight giá trị từ dữ liệu, thay vì chỉ mô tả hiện tượng một cách bề mặt.
#
# -**How I overcame**: Để khắc phục, em đã tìm hiểu thêm các tài liệu và bài viết trên Internet về cách đánh giá một “good data question”, tham khảo các project phân tích dữ liệu được đánh giá cao, đặc biệt chú ý đến cách họ xác định vấn đề và mục tiêu phân tích. Từ đó, em rút ra được kinh nghiệm và điều chỉnh lại câu hỏi nghiên cứu của mình cho phù hợp hơn với dữ liệu và mục tiêu bài toán.
#
# -**Most challenging**: Phần thách thức nhất là việc chuyển từ dữ liệu thô sang một câu hỏi có ý nghĩa phân tích. Điều này khó vì nó đòi hỏi không chỉ kỹ năng kỹ thuật mà còn khả năng tư duy phân tích và hiểu ngữ cảnh.
# ### **Learning & Growth**
# -**What I learned**: Em học được quy trình chuẩn của một dự án phân tích dữ liệu, bao gồm: đặt câu hỏi, tiền xử lý dữ liệu, phân tích khám phá (EDA), xây dựng mô hình Machine Learning và đánh giá kết quả.
#
# -**What surprised me**: Điều khiến em bất ngờ là xu hướng điểm số của nam sinh giảm khi độ tuổi tăng, đặc biệt ở nhóm tuổi 21–22, nơi điểm số có dấu hiệu giảm rõ rệt. Điều này cho thấy tuổi tác và giới tính có thể ảnh hưởng đến kết quả học tập.
#
# -**Shape understanding**: Project giúp em hiểu rằng data science không chỉ là áp dụng thuật toán hay đạt được độ chính xác cao, mà quan trọng hơn là khả năng đặt câu hỏi đúng, diễn giải kết quả và rút ra insight có ý nghĩa.

# %% [markdown]
# ## **Phan Thị Phương Chi - 23120025**
#
# ### **Challenges & Difficulties**
# -**Specific Obstacle**: Trong phần Numerical Analysis, việc xử lý các biến bị lệch (skewed) như absences hay Dalc/Walc là một thử thách để quyết định xem có nên loại bỏ outlier hay giữ lại. Trong phần câu hỏi Q5, việc định nghĩa "Hiệu suất" (Efficiency = G3 / Studytime) gặp khó khăn do studytime là dạng phân loại (1, 2, 3, 4). Với câu hỏi Q6 về Internet, dữ liệu ban đầu cho thấy tác động của Internet không rõ ràng. Rất khó để kết luận nếu chỉ so sánh đơn thuần nhóm Có/Không Internet.
#
# -**How I overcame**: Thử sử dụng các phương pháp Log Transform và Power Transform với các cột bị lệch và đã thấy cải thiện rõ rệt. Với câu Q6, tụi em quyết định chuyển đổi các mức này thành giờ thực tế (1.5h, 3.5h...) để tính toán, nhưng điều này mang tính ước lượng và có thể gây sai số. Với câu Q6, áp dụng phương pháp phân tích đa chiều. Thay vì nhìn Internet độc lập, tôi kết hợp với freetime và goout.
#
# -**Most challenging**: Sau khi trực quan, hầu như các feature không ảnh hưởng trực tiếp đến điểm số G3 một cách rõ ràng. Việc tìm ra các nhóm ảnh hưởng phức tạp đòi hỏi nhiều thời gian thử nghiệm và phân tích sâu hơn.
#
# ### **Learning & Growth**
# -**What I learned**: Học được quy trình chuẩn của một project phân tích dữ liệu, sử dụng các mô hình Machine Learning để dự đoán. Học thêm về các kỹ thuật kiểm định thống kê và trực quan hoá dữ liệu để rút ra insight.
#
# -**What surprised me**: Nam giới và Nữ giới có cách học và ảnh hưởng đến điểm số khác nhau, ví dụ như ở mức studytime thấp thì Nam vượt trội hơn, nhưng ở mức cao thì Nữ lại có điểm số tốt hơn. Internet không có tác động đồng nhất mà phụ thuộc vào các yếu tố khác như freetime và goout. Và mỗi yếu tố đều có ảnh hưởng khác nhau tùy theo ngữ cảnh kết hợp với các yếu tố khác. Ví dụ, Internet có thể giúp ích nhiều cho học sinh có nhiều thời gian rảnh (freetime cao) nhưng lại không giúp gì cho những học sinh thường xuyên đi chơi (goout cao).
#
# -**Shape understanding**: Dữ liệu không chỉ đơn thuần là con số mà còn phản ánh những câu chuyện phức tạp về hành vi con người. Mỗi feature cần có cách xử lý và tiếp cận khác nhau. Việc rút ra insight có ý nghĩa cần kết hợp giữa kiến thức domain cùng vớ1i kỹ năng phân tích dữ liệu chuyên sâu.

# %% [markdown]
# ## **Trần Kim Ngân - 23120060**
#
# ### **Challenges & Difficulties**
# -**Specific Obstacle**: Sự mất cân bằng dữ liệu ở các cột Categorical, làm chúng bị lệch hẳn về một bên $\rightarrow$ Làm cho bài báo cáo có thể không bao hàm đủ đối với những giá trị thiểu số. Và các biến như `Medu`, `Fedu` tương quan khá cao làm khó khăn cho việc xác định yếu tố nào ảnh hưởng thực sự đến điểm số.
#
# -**How I overcame**: Sau khi sử dụng heatmap để phát hiện tương quan, quyết định gộp chúng lại thành 1 biến là `parent_edu` để đưa ra phân tích và nhận xét.
#
# -**Most challenging**: Về câu hỏi sử dụng biến target là `Walc`, ban đầu quyết định sử dụng `total_alc` là mối liên hệ giữa `Dalc` và `Walc` nhưng sau khi phân tích thấy `total_alc` bị lệch một cách nghiêm trọng $\rightarrow$ Phân tích kĩ hơn sẽ thấy các giá trị của `Dalc` rất thấp (ngầm định với việc trong tuần thì các học sinh thường ít có cơ hội để uống rượu hơn so với cuối tuần, và điều đó kéo điểm của `total_alc` xuống gây lệch mô hình). Cho nên với câu hỏi đó sẽ quyết định chỉ sài target là `Walc`.
#
# ### **Learning & Growth**
# -**What I learned**: Học được quy trình chuẩn của một project phân tích dữ liệu, sử dụng các mô hình Machine Learning để dự đoán.
#
# -**What surprised me**: Các học sinh có tần suất uống rượu nhiều thường là do việc có quá nhiều thời gian `free_time` và `goout` nhiều. Còn các thói quen xã hội khác như `romantic`, `activities`,... nhìn chung không ảnh hưởng lắm đến tần suất uống rượu.
#
# -**Shape understanding**: Dữ liệu dùng để kiểm chứng các giả định một cách khách quan hơn thay vì dựa vào cảm tính cá nhân. Đa số mọi người sẽ nghĩ rằng việc uống rượu sẽ bị ảnh hưởng nhiều đến việc có người yêu, tham gia nhiều hoạt động, sử dụng Internet (thấy người khác uống sẽ uống theo), nhưng sau khi phân tích thì việc phân bổ thời gian mới ảnh hưởng đến việc uống rượu nhiều hay ít.
